# %% [markdown]
# ## Step 1

# %% [markdown]
# ## Load Data and Relevent Packages

# %% [markdown]
# **Take note of the type of file you load on Jupyter Notebook**
#
# **Steps to Import an Excel File into Python using Pandas**

# %% [markdown]
# **Step 1.1: Capture the file path**
#
# First, you’ll need to capture the full path where the Excel file is stored on your computer.
#
# For example, let’s suppose that an Excel file is stored under the following path:
#
# C:\Users\Ron\Desktop\Product List.xlsx

# %% [markdown]
# **Step 1.2: Apply the Python code**

# %% [markdown]
# **import pandas as pd**
#
# # Pandas is a software library written for the Python programming language for data manipulation and analysis.
#
# df = pd.read_excel (r'C:\Users\Ron\Desktop\Product List.xlsx') place "r" before the path string to address special character, such as ''. Don't forget to put the file name at the end of the path + '.xlsx'
#
# print (df)

# %% [markdown]
# **Optional Step: Selecting specific sheet tab in the overall spreadsheet**

# %% [markdown]
# **import pandas as pd**
# df = pd.read_excel (r'C:\Users\Ron\Desktop\Product List.xlsx', sheet_name='Name of the sheet')
#
# print(df)

# %% [markdown]
# **How to import csv file in python using jupyter notebook**

# %% [markdown]
# **import pandas as pd**
#
# df = pd.read_csv (r'Path where the CSV file is stored\File name.csv')
#
# print (df)
#
# The data is also imported the same way in python script

# %%
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np

# %%
df_major = pd.read_excel (r'C:\Users\698422\Desktop\Teaching\Teaching\Honours Class\SeptIles_WR_Maj+TE+ModalAbund_MCU1.xlsx', sheet_name='Major_Elements')
print (df_major)
# Out:
#         Sample Cumulus assemblage  Height (m)  SiO2 wt %  TiO2 wt %  \
# 0     9-2533.5               po-C     -4210.0      47.59       0.43
# 1       9-2500               po-C     -4182.0      47.32       0.33
# 2     9-2491.5               po-C     -4175.0      48.12       0.53
# 3       9-2464               po-C     -4153.0      47.77       0.24
# 4      9-2456.               po-C     -4148.0      48.34       0.34
# ..         ...                ...         ...        ...        ...
# 182   RS 07-88               po-C       461.0      46.33       1.39
# 183   RS 07-89               po-C       483.0      46.74       0.65
# 184   RS 07-92               po-C       505.0      44.97       0.63
# 185   RS 07-96               po-C       527.0      45.18       1.62
# 186  RS 07-102               po-C       549.0      40.79       2.81
#
#      Al2O3 wt %  FeOt wt %  MnO wt %  MgO wt %  CaO wt %  Na2O wt %  K2O wt %  \
# ...

# %%
df_major.head()
# Out:
#      Sample Cumulus assemblage  Height (m)  SiO2 wt %  TiO2 wt %  Al2O3 wt %  \
# 0  9-2533.5               po-C     -4210.0      47.59       0.43       21.91
# 1    9-2500               po-C     -4182.0      47.32       0.33       20.50
# 2  9-2491.5               po-C     -4175.0      48.12       0.53       22.91
# 3    9-2464               po-C     -4153.0      47.77       0.24       23.26
# 4   9-2456.               po-C     -4148.0      48.34       0.34       23.40
#
#    FeOt wt %  MnO wt %  MgO wt %  CaO wt %  Na2O wt %  K2O wt %  P2O5 wt %  \
# 0       7.90      0.11      8.63     10.05       2.81      0.22       0.03
# 1       8.91      0.13      9.96      9.00       3.05      0.35       0.06
# 2       6.79      0.09      7.73     10.83       2.79      0.21       0.05
# 3       6.13      0.09      7.17     10.60       3.24      0.23       0.02
# 4       6.13      0.08      6.61     11.15       3.26      0.25       0.01
#
#    LOI wt %  Total wt %  Mg#2
# ...

# %%
df_major.tail()
# Out:
#         Sample Cumulus assemblage  Height (m)  SiO2 wt %  TiO2 wt %  \
# 182   RS 07-88               po-C       461.0      46.33       1.39
# 183   RS 07-89               po-C       483.0      46.74       0.65
# 184   RS 07-92               po-C       505.0      44.97       0.63
# 185   RS 07-96               po-C       527.0      45.18       1.62
# 186  RS 07-102               po-C       549.0      40.79       2.81
#
#      Al2O3 wt %  FeOt wt %  MnO wt %  MgO wt %  CaO wt %  Na2O wt %  K2O wt %  \
# 182       19.51      11.21      0.15      7.67      9.40       2.71      0.31
# 183       20.22       8.76      0.12     10.16     10.41       1.73      0.38
# 184       21.07       9.82      0.12     10.45     10.14       1.85      0.22
# 185       20.35      11.14      0.13      8.43     10.71       2.08      0.21
# 186       20.80      12.68      0.11      4.15     10.83       3.03      0.32
#
#      P2O5 wt %  LOI wt %  Total wt %  Mg#2
# 182       0.20      0.06       98.94  55.0
# ...

# %% [markdown]
# ## Exploratory Data Analysis(EDA) in Python!

# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# In this step, we will perform the below operations to check what the data set comprises of. We will check the below things:
#
# 1. the shape of the dataset
# 2. info of the dataset
# 2. summary of the dataset

# %% [markdown]
# # Shape of the dataset

# %%
#The shape attribute tells us a number of observations and variables we have in the data set. It is used to check the dimension of data. 
df_major.shape
# Out:
# (187, 16)

# %% [markdown]
# # Info of the dataset

# %%
#info() is used to check the Information about the data and the datatypes of each respective attribute.
df_major.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sample              187 non-null    object
#  1   Cumulus assemblage  187 non-null    object
#  2   Height (m)          187 non-null    float64
#  3   SiO2 wt %           187 non-null    float64
#  4   TiO2 wt %           187 non-null    float64
#  5   Al2O3 wt %          187 non-null    float64
#  6   FeOt wt %           187 non-null    float64
#  7   MnO wt %            187 non-null    float64
#  8   MgO wt %            187 non-null    float64
#  9   CaO wt %            187 non-null    float64
#  10  Na2O wt %           187 non-null    float64
#  11  K2O wt %            187 non-null    float64
#  12  P2O5 wt %           187 non-null    float64
#  13  LOI wt %            187 non-null    float64
#  14  Total wt %          187 non-null    float64
# ...

# %%
#The described method will help to see how data has been spread for numerical values. 
# We can clearly see the minimum value, mean values, different percentile values, and maximum values.
df_major.describe()
# Out:
#         Height (m)   SiO2 wt %   TiO2 wt %  Al2O3 wt %   FeOt wt %  \
# count   187.000000  187.000000  187.000000  187.000000  187.000000
# mean  -1890.204813   41.710321    4.109679   17.137112   16.170856
# std    1348.626900    6.065746    2.971360    4.309358    7.666643
# min   -4210.000000   12.210000    0.130000    2.610000    3.300000
# 25%   -2818.000000   39.440000    1.625000   14.520000   11.330000
# 50%   -2155.000000   42.290000    3.630000   17.020000   15.330000
# 75%    -830.000000   45.795000    5.815000   20.250000   19.205000
# max     549.000000   52.270000   15.270000   27.030000   54.470000
#
#          MnO wt %    MgO wt %    CaO wt %   Na2O wt %    K2O wt %   P2O5 wt %  \
# count  187.000000  187.000000  187.000000  187.000000  187.000000  187.000000
# mean     0.169572    7.342567    9.955615    2.653262    0.210588    0.273262
# std      0.070229    2.426796    1.934962    0.725352    0.188118    0.944802
# ...

# %% [markdown]
# #Handling missing value

# %%
df_major.describe().isnull().sum()
# Out:
# Height (m)    0
# SiO2 wt %     0
# TiO2 wt %     0
# Al2O3 wt %    0
# FeOt wt %     0
# MnO wt %      0
# MgO wt %      0
# CaO wt %      0
# Na2O wt %     0
# K2O wt %      0
# P2O5 wt %     0
# LOI wt %      0
# Total wt %    0
# Mg#2          0
# dtype: int64

# %% [markdown]
# # Slicing Data from the data frame

# %%
df_po_c = df_major[ df_major['Cumulus assemblage'] == 'po-C' ]
df_po_c
# Out:
#         Sample Cumulus assemblage  Height (m)  SiO2 wt %  TiO2 wt %  \
# 0     9-2533.5               po-C     -4210.0      47.59       0.43
# 1       9-2500               po-C     -4182.0      47.32       0.33
# 2     9-2491.5               po-C     -4175.0      48.12       0.53
# 3       9-2464               po-C     -4153.0      47.77       0.24
# 4      9-2456.               po-C     -4148.0      48.34       0.34
# 5       9-2451               po-C     -4142.0      49.17       0.13
# 6       9-2410               po-C     -4108.0      47.80       0.46
# 7     9-2334.5               po-C     -4047.0      46.79       0.51
# 8       9-2296               po-C     -4015.0      45.61       0.51
# 9     9-2267.5               po-C     -3992.0      46.55       0.21
# 10      9-2263               po-C     -3988.0      46.52       0.30
# 11      9-2236               po-C     -3966.0      48.28       0.49
# 12      9-2202               po-C     -3939.0      45.70       0.58
# ...

# %%
df_po_c.describe()
# Out:
#         Height (m)  SiO2 wt %  TiO2 wt %  Al2O3 wt %  FeOt wt %   MnO wt %  \
# count    28.000000  28.000000  28.000000   28.000000  28.000000  28.000000
# mean  -2860.857143  46.633214   0.703571   21.523571   8.739286   0.112143
# std    1971.882100   1.753131   0.558306    2.036723   2.359119   0.025438
# min   -4210.000000  40.790000   0.130000   15.120000   5.540000   0.080000
# 25%   -4062.250000  46.172500   0.347500   20.545000   6.962500   0.090000
# 50%   -3872.000000  46.765000   0.520000   21.495000   8.515000   0.110000
# 75%   -2674.000000  47.770000   0.827500   22.997500   9.840000   0.130000
# max     549.000000  49.170000   2.810000   24.500000  14.720000   0.180000
#
#         MgO wt %   CaO wt %  Na2O wt %   K2O wt %  P2O5 wt %   LOI wt %  \
# count  28.000000  28.000000  28.000000  28.000000  28.000000  28.000000
# mean    8.774286  10.137143   2.656786   0.238929   0.062143   0.150714
# std     2.229766   0.831557   0.463282   0.063090   0.063032   0.242776
# ...

# %% [markdown]
# ## Data Visualization

# %%
# Import two important packages:

# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=df_major, hue='Cumulus assemblage', x='Al2O3 wt %', y='SiO2 wt %')
plt.legend(loc=2)
plt.savefig('scatter.png')
plt.xlabel('Al2O3 wt %')
plt.ylabel('SiO2 wt %')
plt.show()

# %% [markdown]
# **You can change the position of the Legend**

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=df_major, hue='Cumulus assemblage', x='Al2O3 wt %', y='SiO2 wt %')
plt.legend(loc=2)
plt.savefig('scatter.png')
plt.xlabel('Al2O3 wt %')
plt.ylabel('SiO2 wt %')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, title='Cumulus assemblage')
plt.show()

# %% [markdown]
# # Multiple Pariplots

# %%
sns.pairplot(
    data=df_major,hue="Cumulus assemblage",
    x_vars=["SiO2 wt %", "TiO2 wt %", "FeOt wt %","CaO wt %"],
    y_vars=["SiO2 wt %","TiO2 wt %","FeOt wt %","CaO wt %"])

# %% [markdown]
# # Creating a Boxplots
#
# Used to identify outliers

# %%
sns.boxplot(y='Mg#2', x='Cumulus assemblage', 
                 data=df_major, 
                 width=0.5,
                 palette="colorblind")
plt.title("Identification of outliers")
plt.suptitle("")
plt.xlabel("Cumulus assemblage")
plt.ylabel("Mg#")
plt.show()

# %% [markdown]
# # Depth plot againts Mg#

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=df_major, hue='Cumulus assemblage', x='Mg#2', y='Height (m)')
plt.legend(loc=2)
plt.savefig('scatter.png')
plt.xlabel('Mg#')
plt.ylabel('Depth (m)')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, title='Cumulus assemblage')
plt.show()

# %% [markdown]
# # Histogram Plots

# %%
sns.histplot(data=df_major, x="FeOt wt %", hue="Cumulus assemblage")
# Out:
# <AxesSubplot:xlabel='FeOt wt %', ylabel='Count'>

# %%
sns.histplot(data=df_major, x="FeOt wt %", hue="Cumulus assemblage", multiple="stack")
# Out:
# <AxesSubplot:xlabel='FeOt wt %', ylabel='Count'>

# %% [markdown]
# # Merging columns

# %%
sum_column = df_major["Na2O wt %"] + df_major["K2O wt %"]
df_major["Na2O wt % + K2O wt %"] = sum_column
print(df_major)
df_major.head()
# Out:
#         Sample Cumulus assemblage  Height (m)  SiO2 wt %  TiO2 wt %  \
# 0     9-2533.5               po-C     -4210.0      47.59       0.43
# 1       9-2500               po-C     -4182.0      47.32       0.33
# 2     9-2491.5               po-C     -4175.0      48.12       0.53
# 3       9-2464               po-C     -4153.0      47.77       0.24
# 4      9-2456.               po-C     -4148.0      48.34       0.34
# ..         ...                ...         ...        ...        ...
# 182   RS 07-88               po-C       461.0      46.33       1.39
# 183   RS 07-89               po-C       483.0      46.74       0.65
# 184   RS 07-92               po-C       505.0      44.97       0.63
# 185   RS 07-96               po-C       527.0      45.18       1.62
# 186  RS 07-102               po-C       549.0      40.79       2.81
#
#      Al2O3 wt %  FeOt wt %  MnO wt %  MgO wt %  CaO wt %  Na2O wt %  K2O wt %  \
# ...

# %%
sns.boxplot(y='Na2O wt % + K2O wt %', x='Cumulus assemblage', 
                 data=df_major, 
                 width=0.5,
                 palette="colorblind")
plt.title("Identification of outliers")
plt.suptitle("")
plt.xlabel("Geological Setting")
plt.ylabel("Na2O + K2O (wt %)")
plt.show()

# %% [markdown]
# ## Data Normalization

# %%
cols = ['Na2O wt % + K2O wt %','FeOt wt %', 'MgO wt %']

for col in cols:
    df_major[col[0]] = df_major[col] * 100 / df_major[cols].sum(axis=1)

# %%
df_major.head()
# Out:
#      Sample Cumulus assemblage  Height (m)  SiO2 wt %  TiO2 wt %  Al2O3 wt %  \
# 0  9-2533.5               po-C     -4210.0      47.59       0.43       21.91
# 1    9-2500               po-C     -4182.0      47.32       0.33       20.50
# 2  9-2491.5               po-C     -4175.0      48.12       0.53       22.91
# 3    9-2464               po-C     -4153.0      47.77       0.24       23.26
# 4   9-2456.               po-C     -4148.0      48.34       0.34       23.40
#
#    FeOt wt %  MnO wt %  MgO wt %  CaO wt %  Na2O wt %  K2O wt %  P2O5 wt %  \
# 0       7.90      0.11      8.63     10.05       2.81      0.22       0.03
# 1       8.91      0.13      9.96      9.00       3.05      0.35       0.06
# 2       6.79      0.09      7.73     10.83       2.79      0.21       0.05
# 3       6.13      0.09      7.17     10.60       3.24      0.23       0.02
# 4       6.13      0.08      6.61     11.15       3.26      0.25       0.01
#
# ...

# %% [markdown]
# # Simple TAS plot

# %%
fig,ax = plt.subplots()
sns.scatterplot(data=df_major, hue='Cumulus assemblage', x='SiO2 wt %', y='Na2O wt % + K2O wt %')
#place legend outside top right corner of plot
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, title='Cumulus assemblage')
plt.title('Total alkalis vs. silica (TAS) diagram')
plt.xlabel('SiO2 (wt%)')
plt.ylabel('Na2O + K2O (wt%)')
plt.savefig('scatter.png')
plt.show()

# %%
#Ternary Plots

# %% [markdown]
# **Step 1: Install Ternary plot packages**

# %%
pip install python-ternary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\698422\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# **Step 2: Import the Ternary plot package**

# %%
import ternary

# %%
# Set up the figure.
fig, tax = ternary.figure(scale=100)
fig.set_size_inches(10, 9)

# Plot points.
tax.scatter(df_major[['F', 'M', 'N']].values)

# Plot the points in groups.
for name, group in df_major.groupby('Cumulus assemblage'):
    
    # Note that we have to shuffle the order.
    # This will place F at the top, N on the left.
    # So the column order is: right, top, left.
    points = group[['F', 'M', 'N']].values
    tax.scatter(points, marker='o', label=name)
    
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, title='Cumulus assemblage')

# Corner labels.
fontsize = 15
offset = 0.1
tax.top_corner_label("FeO Total (wt.%)", fontsize=fontsize, offset=0.2)
tax.left_corner_label("alkalis (wt.%)", fontsize=fontsize, offset=offset)
tax.right_corner_label("MgO (wt.%)", fontsize=fontsize, offset=offset)

# Decoration.
tax.boundary(linewidth=1)
tax.gridlines(multiple=10, color="gray")
tax.ticks(axis='lbr', linewidth=1, multiple=20)
tax.get_axes().axis('off')

tax.show()

# %% [markdown]
# ## Trace Elements

# %%
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np

# %%
df_trace = pd.read_excel (r'C:\Users\698422\Desktop\Teaching\Teaching\Honours Class\SeptIles_WR_Maj+TE+ModalAbund_MCU1.xlsx', sheet_name='Trace_Elements')
print (df_trace)
# Out:
#         Sample Cumulus assemblage  Height (m)  Rb ppm  Sr ppm  Y ppm  Zr ppm  \
# 0     9-2533.5               po-C     -4210.0     2.4   749.0    1.7    43.0
# 1       9-2500               po-C     -4182.0     5.5   679.0    3.6    44.5
# 2     9-2491.5               po-C     -4175.0     2.7   742.0    2.1    49.5
# 3       9-2464               po-C     -4153.0     1.2   750.0    0.6    25.4
# 4      9-2456.               po-C     -4148.0     0.8   750.0    2.0    25.0
# ..         ...                ...         ...     ...     ...    ...     ...
# 182   RS 07-88               po-C       461.0     4.6   676.0    8.2    62.2
# 183   RS 07-89               po-C       483.0     6.0   670.0    4.9    33.5
# 184   RS 07-92               po-C       505.0     3.8   643.0    2.5    34.8
# 185   RS 07-96               po-C       527.0     3.0   617.0    5.1    43.7
# 186  RS 07-102               po-C       549.0     NaN     NaN    NaN     NaN
#
# ...

# %%
df_trace.head()
# Out:
#      Sample Cumulus assemblage  Height (m)  Rb ppm  Sr ppm  Y ppm  Zr ppm  \
# 0  9-2533.5               po-C     -4210.0     2.4   749.0    1.7    43.0
# 1    9-2500               po-C     -4182.0     5.5   679.0    3.6    44.5
# 2  9-2491.5               po-C     -4175.0     2.7   742.0    2.1    49.5
# 3    9-2464               po-C     -4153.0     1.2   750.0    0.6    25.4
# 4   9-2456.               po-C     -4148.0     0.8   750.0    2.0    25.0
#
#    Nb ppm  Co ppm  Cu ppm  Ga ppm  Ni ppm  Zn ppm  Ba ppm  Cr ppm  V ppm
# 0     1.0    28.3    14.8    19.7   142.0    48.0   123.0    13.2   61.1
# 1     4.4    61.9    15.0    18.6   183.0    65.6   185.0    14.7   76.8
# 2     2.2    23.8    18.4    21.4   150.0    47.8   124.0    14.8   65.8
# 3     0.6    38.9    18.8    18.3   149.0    49.9   113.0    15.8   69.7
# 4     2.0    32.1    30.7    19.1   146.0    48.6   108.0    16.7   78.6

# %%
df_trace.tail()
# Out:
#         Sample Cumulus assemblage  Height (m)  Rb ppm  Sr ppm  Y ppm  Zr ppm  \
# 182   RS 07-88               po-C       461.0     4.6   676.0    8.2    62.2
# 183   RS 07-89               po-C       483.0     6.0   670.0    4.9    33.5
# 184   RS 07-92               po-C       505.0     3.8   643.0    2.5    34.8
# 185   RS 07-96               po-C       527.0     3.0   617.0    5.1    43.7
# 186  RS 07-102               po-C       549.0     NaN     NaN    NaN     NaN
#
#      Nb ppm  Co ppm  Cu ppm  Ga ppm  Ni ppm  Zn ppm  Ba ppm  Cr ppm  V ppm
# 182     5.3    46.4   122.0    24.4   176.0    92.3   176.0   214.0  124.0
# 183     3.1    68.7    39.3    18.0   331.0    62.5   118.0   463.0   54.7
# 184     2.8    68.5   506.0    21.8   490.0    68.5    93.2   575.0   73.4
# 185     3.4    49.5    27.4    27.0   201.0    86.2    98.8   406.0  159.0
# 186     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN    NaN

# %% [markdown]
# ## Geological Templates

# %%
df_trace.shape
# Out:
# (187, 16)

# %%
df_trace.describe()
# Out:
#         Height (m)      Rb ppm       Sr ppm       Y ppm      Zr ppm  \
# count   187.000000  184.000000   184.000000  184.000000  184.000000
# mean  -1890.204813    2.780978   617.347826    6.917663   47.707609
# std    1348.626900    1.715286   172.548904   11.549650   17.751122
# min   -4210.000000    0.100000   144.000000    0.000000   17.500000
# 25%   -2818.000000    1.900000   508.500000    2.300000   37.200000
# 50%   -2155.000000    2.500000   623.500000    4.850000   45.300000
# 75%    -830.000000    3.200000   724.250000    7.325000   55.925000
# max     549.000000   16.400000  1143.000000  129.000000  163.000000
#
#            Nb ppm      Co ppm      Cu ppm      Ga ppm      Ni ppm      Zn ppm  \
# count  184.000000  184.000000  184.000000  184.000000  184.000000  184.000000
# mean     4.227717   49.637500  103.644022   23.441304  112.075543   99.307065
# std      4.872129   23.242477  134.701824    3.690429  101.858842   49.927934
# ...

# %%
df_trace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sample              187 non-null    object
#  1   Cumulus assemblage  187 non-null    object
#  2   Height (m)          187 non-null    float64
#  3   Rb ppm              184 non-null    float64
#  4   Sr ppm              184 non-null    float64
#  5   Y ppm               184 non-null    float64
#  6   Zr ppm              184 non-null    float64
#  7   Nb ppm              184 non-null    float64
#  8   Co ppm              184 non-null    float64
#  9   Cu ppm              184 non-null    float64
#  10  Ga ppm              184 non-null    float64
#  11  Ni ppm              184 non-null    float64
#  12  Zn ppm              184 non-null    float64
#  13  Ba ppm              180 non-null    float64
#  14  Cr ppm              180 non-null    float64
# ...

# %%
df_trace.describe().isnull().sum()
# Out:
# Height (m)    0
# Rb ppm        0
# Sr ppm        0
# Y ppm         0
# Zr ppm        0
# Nb ppm        0
# Co ppm        0
# Cu ppm        0
# Ga ppm        0
# Ni ppm        0
# Zn ppm        0
# Ba ppm        0
# Cr ppm        0
# V ppm         0
# dtype: int64

# %% [markdown]
# ## Data Visualization using Geological Templates
#
# They can be imported from Pyrolite package
# **pyrolite is available on PyPi, and can be downloaded with pip:**
#
# pyrolite includes some ready-made templates for well-known plots. These can be used to create new plots, or add a
# template to an existing matplotlib.axes.Axes.

# %%
pip install --user pyrolite
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\698422\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Importing Data

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Bivariate Templates**

# %%
from pyrolite.util.classification import TAS
from pyrolite.util.synthetic import normal_frame, random_cov_matrix
# Out:
# C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\numpydoc\docscrape.py:434: UserWarning: potentially wrong underline length...
# Note
# ----- in
# Plots spidergrams for trace elements data. Additional arguments are typically forwarded
# to respective :mod:`matplotlib` functions :func:`~matplotlib.pyplot.plot` and... in the docstring of spider in C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\pyrolite\plot\spider.py.
#   warn(msg)
# C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\numpydoc\docscrape.py:434: UserWarning: potentially wrong underline length...
# Parameters
# ----------- in
# Method for plotting histograms (mode='hist2d'|'hexbin') or kernel density
# esitimates from point data. Convenience access function to... in the docstring of density in C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\pyrolite\plot\__init__.py.
#   warn(msg)
# ...

# %%
from pyrolite.plot.templates import TAS
from pyrolite.util.plot.axes import share_axes
ax = TAS(linewidth=0.5, add_labels=True)
plt.show()

# %% [markdown]
# **You can plot your own dataset on the template**

# %%
from pyrolite.plot.templates import TAS
from pyrolite.util.plot.axes import share_axes
ax = TAS(linewidth=0.5, add_labels=True)
sns.scatterplot(data=df_major, hue='Cumulus assemblage', x='SiO2 wt %', y='Na2O wt % + K2O wt %')
plt.show()

# %%
df = (
normal_frame(
columns=["SiO2 wt %", "Na2O wt %", "K2O wt %", "Al2O3 wt %"],
mean=[0.5, 0.04, 0.05, 0.4],
size=100,
seed=49,
)
* 100
)
df.head(3)
# Out:
#    SiO2 wt %  Na2O wt %  K2O wt %  Al2O3 wt %
# 0  48.597785   3.833775  4.695366   42.873074
# 1  50.096300   3.960378  5.196130   40.747192
# 2  51.381566   4.126436  5.181051   39.310947

# %% [markdown]
# # Density and Contour Plots

# %%
ax = df_major.loc[:, ["SiO2 wt %", "MgO wt %"]].pyroplot.density()
df_major.loc[:, ["SiO2 wt %", "MgO wt %"]].pyroplot.scatter(ax=ax, s=10, alpha=0.3, c="k", zorder=2)
plt.show()

# %%
ax = df_major.loc[:, ["SiO2 wt %", "MgO wt %"]].pyroplot.density(colorbar=True)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12, 5))
df_major.loc[:, ["SiO2 wt %", "MgO wt %"]].pyroplot.density(ax=ax[0])
df_major.loc[:, ["SiO2 wt %", "CaO wt %"]].pyroplot.density(ax=ax[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Normalization
#
# A selection of reference compositions are included in pyrolite, and can be easily accessed with pyrolite.geochem.norm.get_reference_composition() (see the list at the bottom of the page for a complete list):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pyrolite.plot
from pyrolite.geochem.ind import REE
from pyrolite.geochem.norm import get_reference_composition, all_reference_compositions

# %%
chondrite = get_reference_composition("Chondrite_PON")

# %% [markdown]
# **To use the compositions with a specific set of units, you can change them with set_units():**

# %%
CI = chondrite.set_units("ppm")

# %% [markdown]
# # Spiderplots & Density Spiderplots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pyrolite.util.synthetic import example_spider_data
normdf = example_spider_data(start="EMORB_SM89", norm_to="PM_PON")

# %% [markdown]
# **Normalisation**
#
# Basic spider plots are straightforward to produce:

# %%
import pyrolite.plot
ax = normdf.pyroplot.spider(color="0.5", alpha=0.5, unity_line=True, figsize=(10, 4))
ax.set_ylabel("X / $X_{Primitive Mantle}$")
plt.show()

# %% [markdown]
# **Index Ordering**

# %%
from pyrolite.geochem.ind import by_incompatibility
ax = normdf.pyroplot.spider(
color="k",
alpha=0.1,
unity_line=True,
index_order="incompatibility",
figsize=(10, 4),
)
ax.set_ylabel("X / $X_{Primitive Mantle}$")
plt.show()

# %% [markdown]
# **Filled Ranges**

# %%
ax = normdf.pyroplot.spider(
mode="fill",
color="green",
alpha=0.5,
unity_line=True,
index_order="incompatibility",
figsize=(10, 4),
)
ax.set_ylabel("X / $X_{Primitive Mantle}$")
plt.show()

# %% [markdown]
# ## TAS Classifier

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from pyrolite.util.classification import TAS
from pyrolite.util.synthetic import normal_frame, random_cov_matrix

# %%
df = (
    normal_frame(
        columns=["SiO2", "Na2O", "K2O", "Al2O3"],
        mean=[0.5, 0.04, 0.05, 0.4],
        size=100,
        seed=49,
    )
    * 100
)

df.head(3)
# Out:
#         SiO2      Na2O       K2O      Al2O3
# 0  48.597785  3.833775  4.695366  42.873074
# 1  50.096300  3.960378  5.196130  40.747192
# 2  51.381566  4.126436  5.181051  39.310947

# %% [markdown]
# **We can visualise how this chemistry corresponds to the TAS diagram:**

# %%
import pyrolite.plot

df["Na2O + K2O"] = df["Na2O"] + df["K2O"]
cm = TAS()

fig, ax = plt.subplots(1)
cm.add_to_axes(ax, alpha=0.5, linewidth=0.5, zorder=-1, add_labels=True)
df[["SiO2", "Na2O + K2O"]].pyroplot.scatter(ax=ax, c="k", alpha=0.2)
plt.show()

# %% [markdown]
# **We can now classify this data according to the fields of the TAS diagram, and add this as a column to the dataframe. Similarly, we can extract which rock names the TAS fields correspond to:**

# %%
df["TAS"] = cm.predict(df)
df["Rocknames"] = df.TAS.apply(lambda x: cm.fields.get(x, {"name": None})["name"])
df["Rocknames"].sample(10)  # randomly check 10 sample rocknames
# Out:
# 78    [Phonotephrite, Foid Monzodiorite]
# 2     [Phonotephrite, Foid Monzodiorite]
# 56    [Phonotephrite, Foid Monzodiorite]
# 41    [Phonotephrite, Foid Monzodiorite]
# 93    [Phonotephrite, Foid Monzodiorite]
# 60    [Phonotephrite, Foid Monzodiorite]
# 61    [Phonotephrite, Foid Monzodiorite]
# 47    [Phonotephrite, Foid Monzodiorite]
# 4            [Trachyandesite, Foidolite]
# 12           [Trachyandesite, Foidolite]
# Name: Rocknames, dtype: object

# %% [markdown]
# **We could now take the TAS classes and use them to colorize our points for plotting on the TAS diagram, or more likely, on another plot. Here the relationship to the TAS diagram is illustrated:**

# %%
fig, ax = plt.subplots(1)

cm.add_to_axes(ax, alpha=0.5, linewidth=0.5, zorder=-1, add_labels=True)
df[["SiO2", "Na2O + K2O"]].pyroplot.scatter(ax=ax, c=df["TAS"], alpha=0.7)
# Out:
# <AxesSubplot:xlabel='SiO2', ylabel='Na2O + K2O'>

# %%
from pyrolite.plot.templates import QAP, FeldsparTernary, USDASoilTexture
ax = QAP(linewidth=0.4)
plt.show()
ax = USDASoilTexture(linewidth=0.4)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
FeldsparTernary(ax=ax[0], linewidth=0.4, add_labels=True, mode="default")
FeldsparTernary(ax=ax[1], linewidth=0.4, add_labels=True, mode="miscibility-gap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mineral Database

# %% [markdown]
# **pyrolite includes a limited mineral database which is useful for looking up endmember compositions**

# %%
import pandas as pd

from pyrolite.mineral.mindb import (get_mineral, get_mineral_group,
                                    list_formulae, list_groups, list_minerals)

pd.set_option("display.precision", 3)  # smaller outputs

# %% [markdown]
# **From the database, you can get the list of its contents using a few utility functions:**

# %%
list_groups()
# Out:
# ['amphibole',
#  'pyroxene',
#  'epidote',
#  'mica',
#  'garnet',
#  'feldspar',
#  'olivine',
#  'spinel']

# %%
list_minerals()
# Out:
# ['gedrite',
#  'clintonite',
#  'manganiceladonite',
#  'ferrotschermakite',
#  'majorite',
#  'allanite',
#  'grossular',
#  'pyrope',
#  'pargasite',
#  'winchite',
#  'eckermanite',
#  'polylithionite',
#  'tschermakite',
#  'kosmochlor',
#  'jadeite',
#  'namansilite',
#  'ferroeckermanite',
#  'arvedsonite',
#  'magnesiochromite',
#  'riebeckite',
#  'ferroceladonite',
#  'ferrosilite',
#  'katophorite',
#  'spinel',
#  'ferrorichterite',
#  'muscovite',
#  'ferroedenite',
#  'morimotoite',
#  'spodumene',
#  'johannsenite',
#  'magnesioarfvedsonite',
#  'chromoceladonite',
#  'chromphyllite',
#  'taramite',
#  'ferropargasite',
#  'andradite',
#  'uvarovite',
#  'diopside',
#  'trilithionite',
#  'tremolite',
#  'phengite',
#  'tephroite',
#  'aluminoceladonite',
#  'chromite',
#  'glaucophane',
#  'ferrokaersutite',
#  'magnetite',
#  'ferrokatophorite',
#  'clinozoisite',
#  'piemontite',
#  'celadonite',
#  'ferroaluminoceladonite',
#  'phlogopite',
#  'edenite',
# ...

# %%
list_formulae()
# Out:
# ['Na(Ca2)(Fe4Al)(Si6Al2)O22(OH)2',
#  'Na(Na2)(Fe4Al)(Si8)O22(OH)2',
#  'Ca3Al2(SiO4)3',
#  'Na(NaCa)(Fe5)(Si8)O22(OH)2',
#  'Na(Ca2)(Fe{2+}4Fe{3+})(Si6Al2)O22(OH)2',
#  'K2(Mg2Cr{3+}2)(Si8)O20(OH)4',
#  'Na(Na2)(Mg4Al)(Si8)O22(OH)2',
#  'MgAl2O4',
#  'K2(Fe{2+}6)(Si6Al2)O20(OH)4',
#  'Na(NaCa)(Mg4Al)(Si7Al)O22(OH)2',
#  'K2(Fe{3+}2Fe{2+}2)(Si8)O20(OH)4',
#  'Fe2SiO4',
#  '(Ca2)(Fe4Al)(Si7Al)O22(OH)2',
#  'Ca2Al2Mn{3+}(Si2O7)(SiO4)O(OH)',
#  'CaFeSi2O6',
#  'CaMgSi2O6',
#  'K2(Mg2Al2)(Si8)O20(OH)4',
#  'K2(Mn{3+}2Mg2)(Si8)O20(OH)4',
#  'Na(Ca2)(Mg4Fe{3+})(Si6Al2)O22(OH)2',
#  'Fe{2+}Fe{3+}2O4',
#  'Na(Ca2)(Mg5)(Si7Al)O22(OH)2',
#  'KAlSi3O8',
#  'K2(Al3Li3)(Si6Al2)O20(OH)4',
#  'K2(Mg6)(Si6Al2)O20(OH)4',
#  'K2(Mg4)(Si4Al6)O20(OH)4',
#  'Ca2Al3(Si2O7)(SiO4)O(OH)',
#  'Mn3Al2(SiO4)3',
#  'Na(Ca2)(Fe5)(Si7Al)O22(OH)2',
#  'CaAl2Si2O8',
#  'K2(Cr{3+}4)(Si6Al2)O20(OH)4',
#  'NaFe{3+}Si2O6',
#  'Fe{2+}Al2O4',
#  'Na(Na2)(Fe{2+}4Fe{3+})(Si8)O22(OH)2',
#  'K2(Al3Mg)(Si7Al)O20(OH)4',
# ...

# %%
get_mineral("forsterite")
# Out:
# name       forsterite
# group         olivine
# formula       Mg2SiO4
# Mg              0.346
# Si                0.2
# O               0.455
# Fe                0.0
# Mn                0.0
# Ni                0.0
# Ca                0.0
# Al                0.0
# Fe{3+}            0.0
# Na                0.0
# Mn{3+}            0.0
# Cr                0.0
# Li                0.0
# Cr{3+}            0.0
# Fe{2+}            0.0
# K                 0.0
# H                 0.0
# Ti                0.0
# Ce{3+}            0.0
# dtype: object

# %% [markdown]
# **If you want to get compositions for all minerals within a specific group, you can use get_mineral_group():**

# %%
get_mineral_group("olivine")
# Out:
#             name         formula     Mg     Si      O     Fe     Mn     Ni
# 0     forsterite         Mg2SiO4  0.346  0.200  0.455  0.000  0.000  0.000
# 1       fayalite         Fe2SiO4  0.000  0.138  0.314  0.548  0.000  0.000
# 2      tephroite         Mn2SiO4  0.000  0.139  0.317  0.000  0.544  0.000
# 3  liebenbergite  Ni1.5Mg0.5SiO4  0.063  0.146  0.333  0.000  0.000  0.458

# %% [markdown]
# ## Mineral Endmember Decomposition

# %%
import pandas as pd
import numpy as np
from pyrolite.mineral.mindb import get_mineral
from pyrolite.mineral.normative import endmember_decompose

# %%
#First we’ll start with a composition of an unknown olivine:
comp = pd.Series({"MgO": 42.06, "SiO2": 39.19, "FeO": 18.75})

# %%
#We can break this down into olivine endmebmers using the endmember_decompose() function:
ed = endmember_decompose(
    pd.DataFrame(comp).T, endmembers="olivine", ord=1, molecular=True
)
ed
# Out:
# name  forsterite  fayalite
# 0         79.994    20.006

# %%
#We can check this by recombining the components with these proportions. We can first lookup the compositions for our endmembers:
em = pd.DataFrame([get_mineral("forsterite"), get_mineral("fayalite")])
em.loc[:, ~(em == 0).all(axis=0)]  # columns not full of zeros
# Out:
#          name    group  formula     Mg     Si      O     Fe
# 0  forsterite  olivine  Mg2SiO4  0.346  0.200  0.455  0.000
# 1    fayalite  olivine  Fe2SiO4  0.000  0.138  0.314  0.548

# %%
#First we have to convert these element-based compositions to oxide-based compositions:
emvalues = (
    em.loc[:, ["Mg", "Si", "Fe"]]
    .pyrochem.to_molecular()
    .fillna(0)
    .pyrochem.convert_chemistry(to=["MgO", "SiO2", "FeO"], molecular=True)
    .fillna(0)
    .pyrocomp.renormalise(scale=1)
)
emvalues
# Out:
#      MgO   SiO2    FeO
# 0  0.667  0.333  0.000
# 1  0.000  0.333  0.667

# %%
#These can now be used with our endmember proportions to regenerate a composition:
recombined = pd.DataFrame(ed.values.flatten() @ emvalues).T.pyrochem.to_weight()
recombined
# Out:
#       MgO    SiO2    FeO
# 0  42.059  39.191  18.75

# %%
#To make sure these compositions are within 0.01 percent:
assert np.allclose(recombined.values, comp.values, rtol=10 ** -4)

# %% [markdown]
# ## CIPW Norm

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyrolite.geochem
from pyrolite.util.meta import pyrolite_datafolder


df = (
    pd.read_csv(pyrolite_datafolder() / "testing" / "CIPW_Verma_Test.csv")
    .dropna(how="all", axis=1)
    .pyrochem.parse_chem()
)
df.pyrochem.compositional = df.pyrochem.compositional.apply(
    pd.to_numeric, errors="coerce"
).fillna(0)
df.loc[:, [c for c in df.columns if "NORM" in c]] = df.loc[
    :, [c for c in df.columns if "NORM" in c]
].apply(pd.to_numeric, errors="coerce")

# %% [markdown]
# **The CIPW Norm can be accessed via pyrolite.mineral.normative.CIPW_norm(), and expects a dataframe as input containing major element oxides (in wt%) and can also use a select set of trace elements (in ppm).**

# %%
from pyrolite.mineral.normative import CIPW_norm

NORM = CIPW_norm(df.pyrochem.compositional)
# Out:
# C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\pyrolite\mineral\normative.py:410: UserWarning: The current CIPW Norm implmentation is under continuting development, and does not yet return expected results.
#   warnings.warn(

# %% [markdown]
# **We can quickly check that this includes mineralogical data:**

# %%
NORM.columns
# Out:
# Index(['quartz', 'zircon', 'potassium metasilicate', 'anorthite',
#        'sodium metasilicate', 'acmite', 'thenardite', 'albite', 'orthoclase',
#        'perovskite', 'nepheline', 'leucite', 'dicalcium silicate',
#        'kaliophilite', 'apatite', 'fluroapatite', 'fluorite', 'pyrite',
#        'chromite', 'ilmenite', 'calcite', 'corundum', 'rutile', 'magnetite',
#        'hematite', 'forsterite', 'fayalite', 'clinoferrosilite',
#        'clinoenstatite', 'ferrosilite', 'enstatite', 'titanite',
#        'wollastonite', 'diopside', 'hypersthene', 'olivine', 'halite',
#        'cancrinite'],
#       dtype='object')

# %% [markdown]
# # The function accepts a few keyword arguments, all to do with the iron compositions and related adjustment/corrections:
#
# Fe_correction = <callable>
# For specifying the Fe-correction method/function. Currently only Le LeMaitre’s correction method is implemented [LeMaitre1976] .
#
# Fe_correction_mode = 'volcanic'
# For specificying the Fe-correction mode where relevant
#
# adjust_all_Fe = False
# Specifying whether you want to adjust all iron compositions, or only those which are partially specified (i.e. only have a singular value for one of FeO, Fe2O3, FeOT, Fe2O3T).
#
# For the purpose of establishing the congruency of our algorithm with Verma’s, we’ll use adjust_all_Fe = True. Notably, this won’t make too much difference to the format of the output, but it will adjust the estimates of normative mineralogy depending on oxidation state.

# %%
NORM = CIPW_norm(df.pyrochem.compositional, adjust_all_Fe=True)
# Out:
# C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\pyrolite\mineral\normative.py:410: UserWarning: The current CIPW Norm implmentation is under continuting development, and does not yet return expected results.
#   warnings.warn(

# %% [markdown]
# **Now we have the normative mineralogical outputs, we can have a look to see how these compare to some relevant geochemical inputs:**

# %%
ax = NORM[["ilmenite", "magnetite"]].pyroplot.scatter(clip_on=False, c=df["TiO2"])
plt.show()

# %%
ax = NORM[["orthoclase", "albite", "anorthite"]].pyroplot.scatter(
    clip_on=False, c=df["K2O"]
)
plt.show()
# Out:
# C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\mpltern\ternary\transforms.py:207: RuntimeWarning: invalid value encountered in true_divide
#   points /= np.sum(points, axis=1)[:, np.newaxis]

# %% [markdown]
# ## Coherency with SINCLAS / IgRoCS

# %%
from pyrolite.mineral.normative import NORM_MINERALS

translation = {
    d["name"]: (d.get("SINCLAS_abbrv", None) or k.upper()) + "_NORM"
    for k, d in NORM_MINERALS.items()
    if (d.get("SINCLAS_abbrv", None) or k.upper()) + "_NORM" in df.columns
}
translation
# Out:
# {'quartz': 'Q_NORM',
#  'zircon': 'ZIR_NORM',
#  'potassium metasilicate': 'KS_NORM',
#  'anorthite': 'AN_NORM',
#  'sodium metasilicate': 'NS_NORM',
#  'acmite': 'AC_NORM',
#  'thenardite': 'TH_NORM',
#  'albite': 'AB_NORM',
#  'orthoclase': 'OR_NORM',
#  'perovskite': 'PER_NORM',
#  'nepheline': 'NE_NORM',
#  'leucite': 'LC_NORM',
#  'dicalcium silicate': 'CS_NORM',
#  'kaliophilite': 'KP_NORM',
#  'apatite': 'AP_NORM',
#  'fluorite': 'FR_NORM',
#  'pyrite': 'PYR_NORM',
#  'chromite': 'CHR_NORM',
#  'ilmenite': 'IL_NORM',
#  'calcite': 'CC_NORM',
#  'corundum': 'C_NORM',
#  'rutile': 'RU_NORM',
#  'magnetite': 'MT_NORM',
#  'forsterite': 'FO_NORM',
#  'fayalite': 'FA_NORM',
#  'clinoferrosilite': 'DIF_NORM',
#  'clinoenstatite': 'DIM_NORM',
#  'ferrosilite': 'HYF_NORM',
#  'enstatite': 'HYM_NORM',
#  'titanite': 'SPH_NORM',
#  'wollastonite': 'WO_NORM',
#  'diopside': 'DI_NORM',
#  'hypersthene': 'HY_NORM',
#  'olivine': 'OL_NORM',
#  'halite': 'HL_NORM',
# ...

# %% [markdown]
# **First we’ll collect the minerals which appear in both dataframes, and then iterate through these to check how close the implementations are.**

# %%
minerals = {
    k: v for (k, v) in translation.items() if (df[v] > 0).sum() and (NORM[k] > 0).sum()
}

# %%
import matplotlib.pyplot as plt
from pyrolite.plot.color import process_color

ncols = 4
nrows = len(minerals.keys()) // ncols + 1 if len(minerals.keys()) % ncols else 0

fig, ax = plt.subplots(
    nrows,
    ncols,
    figsize=(ncols * 2.5, nrows * 2),
)
fig.suptitle("Comparing pyrolite's CIPW Norm to SINCLAS/IgRoCS", fontsize=16)
ax = ax.flat

for ix, (b, a) in enumerate(minerals.items()):
    ax[ix].set_title("\n".join(b.split()), y=0.9, va="top")
    if a in df.columns and b in NORM.columns:
        c = process_color(
            np.abs((df[a] / NORM[b]) - 1),
            cmap="RdBu_r",
            norm=plt.Normalize(vmin=0, vmax=0.1),
        )["c"]
        ax[ix].scatter(df[a], NORM[b], c=c)
    ax[ix].plot([0, df[a].max()], [0, df[a].max()], color="k", ls="--")

for a in ax:
    a.set(xticks=[], yticks=[])  # turn off the ticks
    if not a.collections:  # turn off the axis for empty axes
        a.axis("off")
plt.tight_layout()

# %% [markdown]
# **These normative mineralogical components could be input into mineralogical classifiers, as mentioned above. For example, the IUGS QAP classifier:**

# %%
from pyrolite.util.classification import QAP

clf = QAP()  # build a QAP classifier

qap_data = NORM.loc[:, ["quartz", "orthoclase"]]  #
qap_data["plagioclase"] = NORM.loc[:, ["albite", "anorthite"]].sum(axis=1)
# predict which lithological class each mineralogical composiiton belongs in
# we add a small value to zeros here to ensure points fit in polygons
predicted_classes = clf.predict(qap_data.replace(0, 10e-6).values)
predicted_classes.head()
# Out:
# 0      monzodiorite-monzogabbro
# 1    diorite-gabbro-anorthosite
# 2      monzodiorite-monzogabbro
# 3      monzodiorite-monzogabbro
# 4      monzodiorite-monzogabbro
# dtype: object

# %% [markdown]
# **We can use these predicted classes as a color index also, within the QAP diagram or elsewhere:**

# %%
ax = clf.add_to_axes()
qap_data.pyroplot.scatter(ax=ax, c=predicted_classes, axlabels=False, cmap="tab20c")
plt.show()
# Out:
# C:\Users\698422\AppData\Roaming\Python\Python310\site-packages\mpltern\ternary\transforms.py:207: RuntimeWarning: invalid value encountered in true_divide
#   points /= np.sum(points, axis=1)[:, np.newaxis]

# %%
from pyrolite.plot.templates import TAS

ax = TAS()
components = df.loc[:, ["SiO2"]]
components["alkali"] = df.loc[:, ["Na2O", "K2O"]].sum(axis=1)
# add the predictions from normative mineralogy to the TAS diagram
components.pyroplot.scatter(ax=ax, c=predicted_classes, cmap="tab20c", axlabels=False)
plt.show()
